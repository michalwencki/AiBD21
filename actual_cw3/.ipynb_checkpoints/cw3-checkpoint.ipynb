# %%
from sqlalchemy import create_engine
import psycopg2 as pg
import pandas as pd
import numpy

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)

connection_sqlalchemy = db.connect()

# %%
result_set = db.execute("SELECT * FROM city")  
for r in result_set:  
    print(r)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (11, 'Akron', 103, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (12, 'al-Ayn', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (13, 'al-Hawiya', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (14, 'al-Manama', 11, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (15, 'al-Qadarif', 89, datetime.datetime(2006, 2, 15, 9, 45, 25))
# ...

# %%
df = pd.read_sql('select * from category', con=connection_sqlalchemy)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
#  2   last_update  16 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 512.0+ bytes

# %%
result_set = db.execute("SELECT name FROM category")
for r in result_set:
    print(r)
    
## cw 1
# Out:
# ('Action',)
# ('Animation',)
# ('Children',)
# ('Classics',)
# ('Comedy',)
# ('Documentary',)
# ('Drama',)
# ('Family',)
# ('Foreign',)
# ('Games',)
# ('Horror',)
# ('Music',)
# ('New',)
# ('Sci-Fi',)
# ('Sports',)
# ('Travel',)

# %%
result_set = db.execute("SELECT category_id, name FROM category ORDER BY name ASC")
for r in result_set:
    print(r)
    
## cw 2
# Out:
# (1, 'Action')
# (2, 'Animation')
# (3, 'Children')
# (4, 'Classics')
# (5, 'Comedy')
# (6, 'Documentary')
# (7, 'Drama')
# (8, 'Family')
# (9, 'Foreign')
# (10, 'Games')
# (11, 'Horror')
# (12, 'Music')
# (13, 'New')
# (14, 'Sci-Fi')
# (15, 'Sports')
# (16, 'Travel')

# %%
df = pd.read_sql('select * from film order by release_year asc', con=connection_sqlalchemy)
df.head(1)

## cw 3
# Out:
#    film_id            title  \
# 0      133  Chamber Italian
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
#
#               last_update special_features  \
# 0 2013-05-26 14:50:58.951       [Trailers]
#
#                                             fulltext
# 0  'chamber':1 'fate':4 'husband':11 'italian':2 ...

# %%
df = pd.read_sql('select * from film order by release_year asc', con=connection_sqlalchemy)
df.tail(1)

## cw 3
## wszystkie filmy powstały w tym samym roku i brak informacji o dokładniejszym czasie powstania uniemożliwia
## wybranie filmu najstarszego i najmłodszego
# Out:
#      film_id      title                                        description  \
# 999     1000  Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  language_id  rental_duration  rental_rate  length  \
# 999          2006            1                3         4.99      50
#
#      replacement_cost rating             last_update  \
# 999             18.99  NC-17 2013-05-26 14:50:58.951
#
#                                 special_features  \
# 999  [Trailers, Commentaries, Behind the Scenes]
#
#                                               fulltext
# 999  'ark':2 'boy':12,17 'intrepid':4 'mad':8 'mona...

# %%
df = pd.read_sql('select * from rental',con=connection_sqlalchemy)
df.info()
## sprawdzanie typu rental_date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     16044 non-null  int64
#  1   rental_date   16044 non-null  datetime64[ns]
#  2   inventory_id  16044 non-null  int64
#  3   customer_id   16044 non-null  int64
#  4   return_date   15861 non-null  datetime64[ns]
#  5   staff_id      16044 non-null  int64
#  6   last_update   16044 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(4)
# memory usage: 877.5 KB

# %%
df = pd.read_sql('select rental_date from rental',con=connection_sqlalchemy)
df.head()
## sprawdzanie reprezentacji rental_date
# Out:
#           rental_date
# 0 2005-05-24 22:54:33
# 1 2005-05-24 23:03:39
# 2 2005-05-24 23:04:41
# 3 2005-05-24 23:05:21
# 4 2005-05-24 23:08:07

# %%
df = pd.read_sql('select * from rental',con=connection_sqlalchemy)
start_date='2005-07-01 00:00:00'
end_date='2005-08-01 23:59:59'
mask = (df['rental_date'] > start_date) & (df['rental_date'] <= end_date)
df2=df.loc[mask]
df2.count()

## cw 4
# Out:
# rental_id       7380
# rental_date     7380
# inventory_id    7380
# customer_id     7380
# return_date     7380
# staff_id        7380
# last_update     7380
# dtype: int64

# %%
df = pd.read_sql('select * from rental',con=connection_sqlalchemy)
start_date='2010-01-01 00:00:00'
end_date='2011-02-01 23:59:59'
mask = (df['rental_date'] > start_date) & (df['rental_date'] <= end_date)
df2=df.loc[mask]
df2.count()

## cw 5
# Out:
# rental_id       0
# rental_date     0
# inventory_id    0
# customer_id     0
# return_date     0
# staff_id        0
# last_update     0
# dtype: int64

# %%
df = pd.read_sql('select amount from payment order by amount asc',con=connection_sqlalchemy)
df.tail(1)

## cw 6
# Out:
#        amount
# 14595   11.99

# %%
cnt_ids = pd.read_sql('select country_id, country from country where country=%(coun1)s or country=%(coun2)s or country=%(coun3)s',con=connection_sqlalchemy, params={'coun1':'Poland', 'coun2':'Nigeria', 'coun3':'Bangladesh'})
cnt_ids
## country_id, których potrzebujemy
# Out:
#    country_id     country
# 0          12  Bangladesh
# 1          69     Nigeria
# 2          76      Poland

# %%
city_ids = pd.read_sql('select * from city where country_id=12 or country_id=69 or country_id=76',con=connection_sqlalchemy)
city_ids
# Out:
#     city_id             city  country_id         last_update
# 0        69       Benin City          69 2006-02-15 09:45:25
# 1        97        Bydgoszcz          76 2006-02-15 09:45:25
# 2       133      Czestochowa          76 2006-02-15 09:45:25
# 3       141        Deba Habe          69 2006-02-15 09:45:25
# 4       143            Dhaka          12 2006-02-15 09:45:25
# 5       152     Effon-Alaiye          69 2006-02-15 09:45:25
# 6       217              Ife          69 2006-02-15 09:45:25
# 7       218           Ikerre          69 2006-02-15 09:45:25
# 8       220           Ilorin          69 2006-02-15 09:45:25
# 9       234         Jamalpur          12 2006-02-15 09:45:25
# 10      236  Jastrzebie-Zdrj          76 2006-02-15 09:45:25
# 11      252           Kaduna          69 2006-02-15 09:45:25
# 12      255           Kalisz          76 2006-02-15 09:45:25
# 13      314           Lublin          76 2006-02-15 09:45:25
# ...

# %%
df = pd.read_sql('select * from customer where address_id in (select city_id from address where city_id in (select country_id from city where country_id in (select country_id from country where country=%(coun1)s or country=%(coun2)s or country=%(coun3)s)))',con=connection_sqlalchemy,params={'coun1':'Poland', 'coun2':'Nigeria', 'coun3':'Bangladesh'})
df

## cw 7
# Out:
#    customer_id  store_id first_name last_name  \
# 0            8         2      Susan    Wilson
# 1           65         2       Rose    Howard
# 2           72         2    Theresa    Watson
#
#                                email  address_id  activebool create_date  \
# 0    susan.wilson@sakilacustomer.org          12        True  2006-02-14
# 1     rose.howard@sakilacustomer.org          69        True  2006-02-14
# 2  theresa.watson@sakilacustomer.org          76        True  2006-02-14
#
#               last_update  active
# 0 2013-05-26 14:49:45.738       1
# 1 2013-05-26 14:49:45.738       1
# 2 2013-05-26 14:49:45.738       1

# %%
df = pd.read_sql('select DISTINCT country, country_id from country where country_id in (select city_id from city where city_id in (select address_id from address where address_id in (select address_id from staff)))',con=connection_sqlalchemy)
df

## cw 8
# Out:
#           country  country_id
# 0  American Samoa           3
# 1          Angola           4

# %%
df = pd.read_sql('select * from staff',con=connection_sqlalchemy)
df

## sprawdzenie
# Out:
#    staff_id first_name last_name  address_id                         email  \
# 0         1       Mike   Hillyer           3  Mike.Hillyer@sakilastaff.com
# 1         2        Jon  Stephens           4  Jon.Stephens@sakilastaff.com
#
#    store_id  active username                                  password  \
# 0         1    True     Mike  8cb2237d0679ca88db6464eac60da96345513964
# 1         2    True      Jon  8cb2237d0679ca88db6464eac60da96345513964
#
#                  last_update  \
# 0 2006-05-16 16:13:11.793280
# 1 2006-05-16 16:13:11.793280
#
#                                              picture
# 0  [b'\x89', b'P', b'N', b'G', b'\r', b'\n', b'Z'...
# 1                                               None

# %%
df = pd.read_sql('select count(*) from staff where address_id in (select city_id from address where city_id in (select country_id from city where country_id in (select country_id from country where country=%(coun1)s or country=%(coun2)s)))',con=connection_sqlalchemy,params={'coun1':'Spain', 'coun2':'Argentina'})
df

## cw 9
# Out:
#    count
# 0      0

# %%
df = pd.read_sql('select DISTINCT name, category_id from category where category_id in (select film_id from film_category where film_id in (select film_id from film where film_id in (select inventory_id from inventory where inventory_id in (select inventory_id from rental))))',con=connection_sqlalchemy)
df

##cw 10
# Out:
#            name  category_id
# 0        Action            1
# 1     Animation            2
# 2      Children            3
# 3      Classics            4
# 4   Documentary            6
# 5         Drama            7
# 6        Family            8
# 7       Foreign            9
# 8         Games           10
# 9        Horror           11
# 10        Music           12
# 11          New           13
# 12       Sci-Fi           14
# 13       Sports           15
# 14       Travel           16

# %%
df = pd.read_sql('select name, category_id from category where category_id in (select film_id from film_category where film_id in (select film_id from film where film_id in (select inventory_id from inventory where inventory_id in (select rental_id from rental where customer_id in (select customer_id from customer where address_id in (select address_id from address where city_id in (select city_id from city where country_id in (select country_id from country where country=%(coun)s))))))))',con=connection_sqlalchemy, params={'coun':'United States'})
df

## cw11
# Out:
#     name  category_id
# 0  Drama            7

# %%
df = pd.read_sql('select distinct country from country where country=%(coun)s',con=connection_sqlalchemy, params={'coun':'United States'})
df

## testy do nazwy Ameryki: USA, United States of America, United States?
# Out:
#          country
# 0  United States

# %%
df = pd.read_sql('select inventory_id from rental where customer_id in (select address_id from customer where address_id in (select city_id from address where city_id in (select country_id from city where country_id in (select country_id from country where country=%(coun)s))))',con=connection_sqlalchemy, params={'coun':'United States'})
df

## czy rzeczy są wypożyczane z ameryki?
# Out:
#     inventory_id
# 0           3420
# 1           3226
# 2           1007
# 3           1261
# 4           3350
# 5           3879
# 6           2422
# 7           1700
# 8           3046
# 9            705
# 10          3413
# 11          1836
# 12          1486
# 13          1408
# 14           210
# 15          1594
# 16          3711
# 17          1535
# 18          1314
# 19          2440
# 20          1794
# 21          3938
# 22          3170
# 23          2938
# 24          1185
# 25          1721
# 26          4542
# 27          3658
# 28          4560
# 29          2945
# 30          2019

# %%
df = pd.read_sql('select title, film_id from film where film_id in (select actor_id from film_actor where actor_id in (select actor_id from actor where (first_name=%(fn1)s AND last_name=%(sn1)s) OR (first_name=%(fn2)s AND last_name=%(sn2)s) OR (first_name=%(fn3)s AND last_name=%(sn3)s)))', con=connection_sqlalchemy, params={'fn1':'Olympia', 'fn2':'Julia', 'fn3':'Ellen', 'sn1':'Pfeiffer', 'sn2':'Zellweger', 'sn3':'Presley'})
df
# Out:
#                   title  film_id
# 0  Commandments Express      171
# 1     Brannigan Sunrise       93
# 2        Craft Outfield      186
